# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from statsmodels.tsa.arima.model import ARIMA
from xgboost import XGBRegressor
import torch
import torch.nn as nn
from torch.optim import Adam

# %%
# load dataset
file_path = 'Fuel_Consumption_2000-2022.csv'
data = pd.read_csv(file_path)
data = data[['YEAR', 'COMB (L/100 km)']]
data['YEAR'] = pd.to_datetime(data['YEAR'], format='%Y')
data.set_index('YEAR', inplace=True)

# %%
# Resemple annually
annual_data = data.resample('YE').mean()
scaler = MinMaxScaler()
annual_data['Scaled_Comb'] = scaler.fit_transform(annual_data[['COMB (L/100 km)']])

# %%
# plot ACF and PACF
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(annual_data['COMB (L/100 km)'])
plt.title('ACF - Fuel Consumption')
plt.show()
plot_pacf(annual_data['COMB (L/100 km)'])
plt.title('PACF - Fuel Consumption')
plt.show()

# %%
# Train-Test split
train_size = int(len(annual_data) * 0.67)
train, test = annual_data.iloc[:train_size], annual_data.iloc[train_size:]

# %%
# -- ARIMA -- 
model_arima = ARIMA(train['COMB (L/100 km)'], order=(1, 1, 1))
results_arima = model_arima.fit()
forecast_arima = results_arima.get_forecast(steps=len(test))
arima_pred = forecast_arima.predicted_mean.values
true_values_arima = test['COMB (L/100 km)'].values

# %%
# -- LSTM --
train_tensor = torch.tensor(train[['Scaled_Comb']].values, dtype=torch.float32).view(-1, 1, 1)
test_tensor = torch.tensor(test[['Scaled_Comb']].values, dtype=torch.float32).view(-1, 1, 1)

# %%
class LSTMModel(nn.Module):
    def __init__(self):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size=1, hidden_size=100, batch_first=True)
        self.linear = nn.Linear(100, 1)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        return self.linear(lstm_out[:, -1, :])

model_lstm = LSTMModel()
loss_fn = nn.MSELoss()
optimizer = Adam(model_lstm.parameters(), lr=0.01)
for epoch in range(100):
    model_lstm.train()
    optimizer.zero_grad()
    output = model_lstm(train_tensor)
    loss = loss_fn(output, train_tensor[:, -1, :])
    loss.backward()
    optimizer.step()

model_lstm.eval()
with torch.no_grad():
    lstm_output = model_lstm(test_tensor)
    lstm_pred = scaler.inverse_transform(lstm_output.numpy())

# %%
# -- Lag-based ML models --
annual_data['Lag1'] = annual_data['Scaled_Comb'].shift(1)
ml_data = annual_data.dropna()
X = ml_data[['Lag1']]
y = ml_data['Scaled_Comb']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=len(test)/len(ml_data), shuffle=False)

# %%
# fit all models
models = {
    "XGBoost": XGBRegressor(),
    "LinearRegression": LinearRegression(),
    "Ridge": Ridge(),
    "RandomForest": RandomForestRegressor(),
    "SVR": SVR()
}

predictions = {}
metrics = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    pred_scaled = model.predict(X_test)
    pred_inv = scaler.inverse_transform(pred_scaled.reshape(-1, 1))
    true_inv = scaler.inverse_transform(y_test.values.reshape(-1, 1))
    predictions[name] = pred_inv
    metrics[name] = [
        np.sqrt(mean_squared_error(true_inv, pred_inv)),
        mean_absolute_error(true_inv, pred_inv),
        r2_score(true_inv, pred_inv)
    ]

# %%
# Add ARIMA and LSTM manually
metrics["ARIMA"] = [
    np.sqrt(mean_squared_error(true_values_arima, arima_pred)),
    mean_absolute_error(true_values_arima, arima_pred),
    r2_score(true_values_arima, arima_pred)
]

metrics["LSTM"] = [
    np.sqrt(mean_squared_error(true_values_arima, lstm_pred)),
    mean_absolute_error(true_values_arima, lstm_pred),
    r2_score(true_values_arima, lstm_pred)
]

# %%
# format results
results_df = pd.DataFrame(metrics, index=['RMSE', 'MAE', 'R²']).T.reset_index().rename(columns={'index': 'Model'})

# %%
from tabulate import tabulate
print(tabulate(results_df, headers='keys', tablefmt='github', showindex=False))
# Out:
# | Model            |      RMSE |       MAE |          R² |
# |------------------|-----------|-----------|-------------|
# | XGBoost          | 0.488406  | 0.425187  |  -18.6124   |
# | LinearRegression | 0.456781  | 0.301297  |  -16.1548   |
# | Ridge            | 0.169597  | 0.126274  |   -1.36486  |
# | RandomForest     | 0.318956  | 0.24343   |   -7.36431  |
# | SVR              | 0.201545  | 0.176566  |   -2.33974  |
# | ARIMA            | 1.40405   | 1.37063   | -161.082    |
# | LSTM             | 0.0120944 | 0.0119176 |    0.987974 |

# %%
# Plot
fig, ax = plt.subplots(3, 1, figsize=(12, 16))

# RMSE
sns.barplot(data=results_df, x='Model', y='RMSE', hue='Model', ax=ax[0], palette='Blues_d', legend=False)
ax[0].set_title('RMSE Comparison')

# MAE
sns.barplot(data=results_df, x='Model', y='MAE', hue='Model', ax=ax[1], palette='Greens_d', legend=False)
ax[1].set_title('MAE Comparison')

# R²
sns.barplot(data=results_df, x='Model', y='R²', hue='Model', ax=ax[2], palette='Reds_d', legend=False)
ax[2].set_title('R² Score Comparison')

plt.tight_layout()
plt.show()

# %%
# select best model based on RMSE as baseline
baseline_model = results_df.sort_values(by='RMSE').iloc[0]['Model']
print(f"Choose Baseline Model (Lowest RMSE): {baseline_model}")
# Out:
# Choose Baseline Model (Lowest RMSE): LSTM

# %%
# collect predicted values
predicted_dict = {
    'ARIMA': arima_pred,
    'XGBoost': predictions['XGBoost'],
    'LinearRegression': predictions['LinearRegression'],
    'Ridge': predictions['Ridge'],
    'RandomForest': predictions['RandomForest'],
    'SVR': predictions['SVR']
}

# %%
# get true values from test set (inverse scaled if needed)
true_values = test['COMB (L/100 km)'].values

# %%
# plot: Actual vs Predicted for each model
plt.figure(figsize=(14, 7))
plt.plot(test.index, true_values, label='Actual', marker='o', linewidth=2)
for model_name, y_pred in predicted_dict.items():
    if model_name != "LSTM": #LSTM skipped due to the runtime issue
        plt.plot(test.index, y_pred, label=model_name, linestyle='--', marker='x')

plt.title("Actual vs Predicted Fuel Consumption (All Models)")
plt.xlabel("Year")
plt.ylabel("Fuel Consumption (L/100 km)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# ⚠️ Fallback: Check if baseline_model is available in predictions
if baseline_model not in predicted_dict:
    print(f"⚠️ Warning: {baseline_model} predictions not available. Using next best model.")
    available_models = results_df[results_df['Model'].isin(predicted_dict.keys())]
    baseline_model = available_models.sort_values(by='RMSE').iloc[0]['Model']
    print(f"✅ New baseline model selected: {baseline_model}")
# Out:
# ⚠️ Warning: LSTM predictions not available. Using next best model.
# ✅ New baseline model selected: Ridge

# %%
# Forecast plot for baseline model
forecast_values = predicted_dict[baseline_model].flatten()
plt.figure(figsize=(12, 6))
plt.plot(test.index, true_values, label='Actual', marker='o')
plt.plot(test.index, forecast_values, label=f'Forecast by {baseline_model}', linestyle='--', marker='s')
plt.fill_between(test.index, forecast_values * 0.95, forecast_values * 1.05, color='gray', alpha=0.2, label='±5% Margin')
plt.title(f'Forecast Plot using {baseline_model}')
plt.xlabel('Year')
plt.ylabel('Fuel Consumption (L/100 km)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Recalculate second_best_model from available predictions
available_models = results_df[results_df['Model'].isin(predicted_dict.keys())]
sorted_models = available_models.sort_values(by='RMSE')
baseline_model = sorted_models.iloc[0]['Model']
second_best_model = sorted_models.iloc[1]['Model']

# %%
# Paired forecast plot
plt.figure(figsize=(12, 6))
plt.plot(test.index, true_values, label='Actual', marker='o')
plt.plot(test.index, predicted_dict[baseline_model], label=f'{baseline_model}', linestyle='--')
plt.plot(test.index, predicted_dict[second_best_model], label=f'{second_best_model}', linestyle='-.')
plt.title(f'Forecast Comparison: {baseline_model} vs {second_best_model}')
plt.xlabel('Year')
plt.ylabel('Fuel Consumption (L/100 km)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# ✅ Check if LSTM predictions are available, then evaluate and include
if 'lstm_predictions' in locals():
    true_values_lstm = test['COMB (L/100 km)'].values

    # Calculate evaluation metrics
    rmse_lstm = np.sqrt(mean_squared_error(true_values_lstm, lstm_predictions))
    mae_lstm = mean_absolute_error(true_values_lstm, lstm_predictions)
    r2_lstm = r2_score(true_values_lstm, lstm_predictions)

    # Store in metrics and predictions dictionaries
    metrics['LSTM'] = [rmse_lstm, mae_lstm, r2_lstm]
    predicted_dict['LSTM'] = lstm_predictions

    print("✅ LSTM metrics successfully added:")
    print(f"   RMSE: {rmse_lstm:.4f}, MAE: {mae_lstm:.4f}, R²: {r2_lstm:.4f}")

else:
    print("⚠️ LSTM predictions not found. Skipping LSTM in metrics.")
# Out:
# ⚠️ LSTM predictions not found. Skipping LSTM in metrics.

# %%
# Recalculate valid models
available_models = results_df[results_df['Model'].isin(predicted_dict.keys())]
sorted_models = available_models.sort_values(by='RMSE')
baseline_model = sorted_models.iloc[0]['Model']
second_best_model = sorted_models.iloc[1]['Model']

# %%
plt.figure(figsize=(14, 10))
for i, (name, pred) in enumerate(predicted_dict.items()):
    residuals = test['COMB (L/100 km)'].values - pred.flatten()
    plt.subplot(len(predicted_dict), 1, i+1)
    plt.plot(test.index, residuals, label=f'{name} Residuals', marker='o')
    plt.axhline(0, color='black', linestyle='--')
    plt.legend()
    plt.grid(True)
plt.tight_layout()
plt.show()
